# %%
# ROK ROZMAN
import numpy as np

import matplotlib.pyplot as plt

import PIL # preverite ali imate nameščen paket pillow (funkcija imread)
from PIL import Image
#import cv2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from PIL import Image

#win = image.ImageWin()
#img = Image("slike/236969406_ecc45ed0f1.jpg")
img = Image.open('slike/236969406_ecc45ed0f1.jpg')
W, H = img.size

factor = 2

#W = img.getWidth()
#H = img.getHeight()

#newW = int(W*factor)# ce jih povecamo
#newH = int(H*factor)# ce jih povecamo

newW = int(W/factor) # faktor manjsa
newH = int(H/factor) # faktor manjsa

#newImage = image.EmptyImage(newW, newH)
newImage = Image.new('RGB', (newW, newH))
for col in range(newW):
    for row in range(newH):
        #cordinate = col/factor,row/factor
        cordinate = col*factor,row*factor
        #p = img.getpixel(cordinate)
        p = img.getpixel(cordinate)
        #newImage.putpixel((col,row),p)
        newImage.putpixel((col,row),p)


#newImage.draw(win)

#pyplot.close('all')
I = pyplot.imread('slike/236969406_ecc45ed0f1.jpg') # nalozimo sliko
#I = pyplot.imread('slike/sea-breeze-apartments-pool.jpg')
pyplot.figure()
pyplot.imshow(I) # izrisemo sliko
pyplot.title('originalna slika')
pyplot.figure()
pyplot.imshow(newImage) # izrisemo sliko
pyplot.title('Nova slika')

asd = Image.open('slike/236969406_ecc45ed0f1.jpg')

w, h = asd.size
print('o width: ', w)
print('o height:', h)

w, h = newImage.size
print('width: ', w)
print('height:', h)
# Out:
# o width:  500
# o height: 333
# width:  250
# height: 166
